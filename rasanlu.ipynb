# %%
import pandas as pd

# Đọc file Excel bằng pd.read_excel()
df = pd.read_excel('C:/Users/vuongbahanh/Documents/Dai_hoc/Ki1_2025/Lab/chatbot dataset v4 (2).xlsx')

# Hiển thị thông tin về DataFrame
df["Chi tiết hơn"].unique() #Lấy các loại giá trị của Intent

df.columns

# filtered_quest = df[df['Intent'] == 'Thông tin thị trường chứng khoán']['Câu hỏi'] #Lấy các câu hỏi liên có intent là OTP

# filtered_quest
# Out:
# array([nan, 'lịch sử', 'Phí giao dịch', 'Giờ mở cửa, đóng cửa', 'số dư',
#        'các mã cổ phiếu đã mua', 'biến động các cổ phiếu đã mua',
#        'giao dịch phái sinh', 'Đồng ý', 'từ chối', 'không rõ',
#        'đặt lệnh bán', 'check lệnh bán',
#        'truy vấn đã bán được bao nhiêu cổ phiếu', 'cổ phiếu bao giờ về',
#        'tổng giá trị bán', 'phí bán', 'thuế bán', 'số điện thoại',
#        'email', 'zalo', 'facebook', 'messenger', 'hỏi tên đăng nhập',
#        'Than'], dtype=object)
