# %%
import pandas as pd

# Đọc file Excel bằng pd.read_excel()
df = pd.read_excel('C:/Users/vuongbahanh/Documents/Dai_hoc/Ki1_2025/Lab/chatbot dataset v4 (2).xlsx')

# Hiển thị thông tin về DataFrame
df["Chi tiết hơn"].unique() #Lấy các loại giá trị của Intent

# df.columns

# filtered_quest = df[df['Intent'] == 'Thông tin thị trường chứng khoán']['Câu hỏi'] #Lấy các câu hỏi liên có intent là OTP

# filtered_quest
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Input In [1], in <cell line: 8>()
#       1 # import pandas as pd
#       2
#       3 # # Đọc file Excel bằng pd.read_excel()
#    (...)
#       6 # # Hiển thị thông tin về DataFrame
#       7 # df["Chi tiết hơn"].unique() #Lấy các loại giá trị của Intent
# ----> 8 from rasa.nlu.model import Interpreter
#       9 import json
#      11 def predict_intent(text):
#      12     # Nạp mô hình NLU
#
# ImportError: cannot import name 'Interpreter' from 'rasa.nlu.model' (c:\Users\vuongbahanh\Documents\Dai_hoc\Ki1_2025\Lab\venv\lib\site-packages\rasa\nlu\model.py)
